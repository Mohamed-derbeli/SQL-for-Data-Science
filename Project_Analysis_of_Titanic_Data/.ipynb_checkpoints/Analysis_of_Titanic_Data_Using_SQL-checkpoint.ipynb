# %%
import pandas as pd
import pandasql as ps
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic['PassengerID']=range(1,1+len(titanic))
titanic=titanic.rename(columns={'home.dest':'home_dest'})

# %%
ps.sqldf("""SELECT *
            FROM titanic 
            LIMIT 5""")
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked  boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S     2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S    11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  None    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  None  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  None    NaN
#
#                          home_dest  PassengerID
# 0                     St Louis, MO            1
# 1  Montreal, PQ / Chesterville, ON            2
# 2  Montreal, PQ / Chesterville, ON            3
# 3  Montreal, PQ / Chesterville, ON            4
# 4  Montreal, PQ / Chesterville, ON            5

# %% [markdown]
# ## Analyse of Survived Passengers
#
# #### Total survived:

# %%
ps.sqldf("""SELECT COUNT(*)
            FROM titanic
            WHERE survived=1  """)
# Out:
#    COUNT(*)
# 0       500

# %% [markdown]
# ## Analyse of Classs:

# %%
ps.sqldf("""SELECT survived, pclass, COUNT(*) AS Count
            FROM titanic 
            GROUP BY survived, pclass
            ORDER BY Count DESC  """)
# Out:
#    survived  pclass  Count
# 0       0.0     3.0    528
# 1       1.0     1.0    200
# 2       1.0     3.0    181
# 3       0.0     2.0    158
# 4       0.0     1.0    123
# 5       1.0     2.0    119
# 6       NaN     NaN      1

# %% [markdown]
# ## Analyse of sex:

# %%
ps.sqldf("""SELECT survived, sex, COUNT(*) AS Count
            FROM titanic 
            GROUP BY survived, sex
            ORDER BY Count DESC  """)
# Out:
#    survived     sex  Count
# 0       0.0    male    682
# 1       1.0  female    339
# 2       1.0    male    161
# 3       0.0  female    127
# 4       NaN    None      1

# %% [markdown]
# ## Analyse of Age

# %%
titanic=ps.sqldf(""" SELECT *,
                     CASE WHEN age is NULL THEN 'Missing'
                          WHEN age <18 THEN '1-17'
                      WHEN age <60 THEN '18-60'
                     ELSE '60+' 
                     END AS age_interval
                     FROM titanic """)

# %%
ps.sqldf(""" SELECT survived, age_interval, COUNT(*) AS Count
             FROM titanic
             GROUP BY survived, age_interval
             ORDER BY Count DESC
             limit 10""")
# Out:
#    survived age_interval  Count
# 0       0.0        18-60    518
# 1       1.0        18-60    334
# 2       0.0      Missing    190
# 3       1.0         1-17     81
# 4       0.0         1-17     73
# 5       1.0      Missing     73
# 6       0.0          60+     28
# 7       1.0          60+     12
# 8       NaN      Missing      1

# %% [markdown]
# #### Oldest passengers

# %%
ps.sqldf("""SELECT passengerID, name, sex, survived, MAX(age) as age
            FROM titanic  """)
# Out:
#    PassengerID                                  name   sex  survived   age
# 0           15  Barkworth, Mr. Algernon Henry Wilson  male       1.0  80.0

# %% [markdown]
# #### Youngest passanger

# %%
ps.sqldf("""SELECT passengerID, name, sex, survived, MIN(age) as age
            FROM titanic  """)
# Out:
#    PassengerID                                     name     sex  survived  \
# 0          764  Dean, Miss. Elizabeth Gladys "Millvina"  female       1.0
#
#       age
# 0  0.1667

# %% [markdown]
# ## Analyse of the Embarked

# %%
ps.sqldf("""SELECT survived, embarked, COUNT(*) as Count
            FROM titanic
            GROUP BY survived, embarked
            ORDER BY Count DESC""")
# Out:
#    survived embarked  Count
# 0       0.0        S    610
# 1       1.0        S    304
# 2       1.0        C    150
# 3       0.0        C    120
# 4       0.0        Q     79
# 5       1.0        Q     44
# 6       1.0     None      2
# 7       NaN     None      1

# %% [markdown]
# ## Analyse of the boat ID

# %%
ps.sqldf(""" SELECT  boat, COUNT(*) AS Count
             FROM  titanic
             GROUP BY boat
             ORDER BY Count DESC""")
# Out:
#        boat  Count
# 0      None    824
# 1        13     39
# 2         C     38
# 3        15     37
# 4        14     33
# 5         4     31
# 6        10     29
# 7         5     27
# 8         3     26
# 9         9     25
# 10       11     25
# 11        8     23
# 12        7     23
# 13       16     23
# 14        D     20
# 15        6     20
# 16       12     19
# 17        2     13
# 18        A     11
# 19        B      9
# 20        1      5
# 21      C D      2
# 22      5 7      2
# 23    13 15      2
# 24     8 10      1
# 25      5 9      1
# 26    15 16      1
# 27  13 15 B      1

# %% [markdown]
# ## Analyse of home dest

# %%
ps.sqldf("""SELECT home_dest, COUNT(*) as Count
            FROM titanic
            GROUP BY home_dest
            ORDER BY Count DESC
            LIMIT 10""")
# Out:
#                               home_dest  Count
# 0                                  None    565
# 1                          New York, NY     64
# 2                                London     14
# 3                          Montreal, PQ     10
# 4                         Paris, France      9
# 5                  Cornwall / Akron, OH      9
# 6                          Winnipeg, MB      8
# 7  Wiltshire, England Niagara Falls, NY      8
# 8                      Philadelphia, PA      8
# 9                   Sweden Winnipeg, MN      7

# %% [markdown]
# ## Aggregating Information

# %%
ps.sqldf(""" SELECT  sex,
                     embarked,
                     survived,
                     AVG(age) AS avg_age,
                     MIN(age) AS min_age,
                     MAX(age) AS max_age,
                     COUNT(PassengerID) AS total_passengers,
                     COUNT(DISTINCT ticket) as unique_tickets
             FROM titanic
             GROUP BY embarked,sex,survived
             ORDER BY total_passengers DESC
""")
# Out:
#        sex embarked  survived    avg_age  min_age  max_age  total_passengers  \
# 0     male        S       0.0  30.855829   0.3333     74.0               517
# 1   female        S       1.0  29.104167   0.1667     76.0               198
# 2     male        C       0.0  35.178082   6.0000     71.0               109
# 3     male        S       1.0  25.712862   0.6667     80.0               106
# 4   female        C       1.0  31.543956   0.7500     64.0               102
# 5   female        S       0.0  24.842105   1.0000     63.0                93
# 6     male        Q       0.0  32.104167   2.0000     70.5                56
# 7     male        C       1.0  29.912602   0.4167     60.0                48
# 8   female        Q       1.0  24.000000  15.0000     37.0                37
# 9   female        Q       0.0  26.692308  17.0000     39.0                23
# 10  female        C       0.0  27.071429   9.0000     50.0                11
# 11    male        Q       1.0  25.000000  21.0000     29.0                 7
# 12  female     None       1.0  50.000000  38.0000     62.0                 2
# 13    None     None       NaN        NaN      NaN      NaN                 1
#
#     unique_tickets
# 0              456
# 1              148
# 2              101
# 3               95
# 4               69
# 5               65
# 6               51
# 7               44
# 8               34
# 9               23
# 10               8
# 11               7
# 12               1
# 13               0

# %% [markdown]
# # Visualisation

# %%
def sub_barplot(X,Y,Xlab,Ylab,titles,nb_rows,nb_columns,fig):
    plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9,wspace=0.3,hspace=1)
    itm=0
    cursor=1
    for i in titles:
        plt.subplot(nb_rows, nb_columns, cursor)
        plt.title('{}'.format(i), fontsize = 12)
        plt.xlabel(Xlab[itm], fontsize = 12)
        plt.ylabel(Ylab[itm], fontsize = 12)
        plt.xticks(rotation=60)
        sns.barplot(X[itm],Y[itm])
        cursor += 1
        itm += 1
    plt.show()

# %%
survived_passengers = titanic.groupby(['survived']).PassengerID.count().sort_values(ascending=False)
survived_sex= titanic[titanic.survived==1].groupby(['sex']).PassengerID.count().sort_values(ascending=False)
survived_class= titanic[titanic.survived==1].groupby(['pclass']).PassengerID.count().sort_values(ascending=False)
survived_age= titanic[titanic.survived==1].groupby(['age_interval']).PassengerID.count().sort_values(ascending=False)
survived_embarked= titanic[titanic.survived==1].groupby(['embarked']).PassengerID.count().sort_values(ascending=False)
survived_boat= titanic[titanic.survived==1].groupby(['boat']).PassengerID.count().sort_values(ascending=False).head(10)
survived_cabin= titanic[titanic.survived==1].groupby(['cabin']).PassengerID.count().sort_values(ascending=False).head(10)
survived_home= titanic[titanic.survived==1].groupby(['home_dest']).PassengerID.count().sort_values(ascending=False).head(10)

# %%
X=[survived_passengers.index, survived_sex.index, survived_class.index, survived_age.index, survived_embarked.index, survived_boat.index,survived_cabin.index,survived_home.index] 
Y=[survived_passengers.values, survived_sex.values, survived_class.values, survived_age.values, survived_embarked.values, survived_boat.values,survived_cabin.values,survived_home.values] 
Xlab=["Survived", "sex", "class","age interval", "embarked", "boat ID", "cabin ID", "home dest"]                                                  
Ylab=['Count','Count','Count','Count','Count','Count','Count','Count']  
titles = ['Survived Vs Dead', 'Survived by sex', 'Survived by Class', 'Survived by age interval', 'Survived by embarked', 'Survived by boat ID', 'Survived by cabin ID', 'Survived by home dest']
fig = plt.figure(figsize=(15,40))
sub_barplot(X,Y,Xlab,Ylab,titles,8,2,fig)
# Out:
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/lib/python3/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
